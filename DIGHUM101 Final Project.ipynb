# %% [markdown]
# # Lyrical Analysis of West Coast Gangster Rap
# ****

# %% [markdown]
# For my project, I have chosen to analyze West Coast rap and hip hop music from differing sides of the rag. I come from an area dominated by the Rollin 60’s Neighborhood Crips, and as such have been exposed to much of the music its members create. When I compare it to music created by the Blood/Piru gangs that claim territory just a couple miles away, the sound is extremely different, with different beat production methods and tools used and an overall different tone/vibe. While it is impossible to analyze those very differences in sound using the processes we have been taught in class, I began to wonder whether the content of their songs/lyrics had a similar differentiation. While the different neighborhoods clearly have different tastes in terms of style of music, do their tastes also vary when it comes to content? Are there patterns in the themes and topics discussed/sung about between the two groups, and/or within the groups themselves?
#
# *Essentially: What are the similarities and differences between crip and blood lyrical choice?*
#
# My expectations are that crip rappers generally will have more topics of meaning within their songs, whereas blood rappers tend to push their credentials more. However, this expectation is borne from the implicit bias of having been raised in a crip dominated neighborhood, and thus having had more negative views of bloods/pirus reinforced from my upbringing.

# %% [markdown]
# ## Data
#
# For my data I chose the top 3 songs based off of number of listens on Spotify for two prominent artists from both sides of the rag. All lyrics are courtesy of Rap Genius.
#
# ### Crip Artists and Songs:
# #### Nipsey Hussle:
# 1. Racks In The Middle (feat. Roddy Richh, Hit-Boy)
# 2. Grinding All My Life
# 3. Dedication (feat. Kendrick Lamar)
#
# #### ScHoolboy Q:
# 1. Man Of The Year
# 2. Numb Numb Juice
# 3. Collard Greens
#
# ### Blood Artists and Songs:
# #### YG:
# 1. Big Bank (feat. 2 Chainz, Big Sean, Nicki Minaj)
# 2. Go Loko (feat. Tyga, Jon Z)
# 3. SUU WHOOP
#
# #### Jay Rock:
# 1. Kings Dead (feat. Kendrick Lamar, Future, James Blake)
# 2. WIN
# 3. Wow Freestyle (feat. Kendrick Lamar)

# %% [markdown]
# ## Process
#
# ### Normalization
# 1. Turn lyrics into .txt files
# 2. Import to the notebook
# 3. Remove punctuation
# 4. Make lowercase
# 5. Tokenize
# 6. Remove stopwords
#
# ### Analysis
# 1. Analyze word frequency
# 2. Convert to a DataFrame
# 3. Part of speech (POS) tagging
#
# ### Visualization
# 1. Barplot of word frequency
# 2. Barplot of word length
#
# ### Summary Statistics
# 1. .describe()

# %%
import pandas as pd

# %% [markdown]
# ## Normalization

# %% [markdown]
# ### Opening Data

# %%
nipsey_1 =  open('/Users/indraimar/Desktop/DH Projects/Nip1.txt', encoding = 'utf-8').read()
nipsey_2 =  open('/Users/indraimar/Desktop/DH Projects/Nip2.txt', encoding = 'utf-8').read()
nipsey_3 =  open('/Users/indraimar/Desktop/DH Projects/Nip3.txt', encoding = 'utf-8').read()
schoolboy_1 = open('/Users/indraimar/Desktop/DH Projects/Q1.txt', encoding = 'utf-8').read()
schoolboy_2 = open('/Users/indraimar/Desktop/DH Projects/Q2.txt', encoding = 'utf-8').read()
schoolboy_3 = open('/Users/indraimar/Desktop/DH Projects/Q3.txt', encoding = 'utf-8').read()
yg_1 = open('/Users/indraimar/Desktop/DH Projects/YG1.txt', encoding = 'utf-8').read()
yg_2 = open('/Users/indraimar/Desktop/DH Projects/YG2.txt', encoding = 'utf-8').read()
yg_3 = open('/Users/indraimar/Desktop/DH Projects/YG3.txt', encoding = 'utf-8').read()
jayrock_1 = open('/Users/indraimar/Desktop/DH Projects/JR1.txt', encoding = 'utf-8').read()
jayrock_2 = open('/Users/indraimar/Desktop/DH Projects/JR2.txt', encoding = 'utf-8').read()
jayrock_3 = open('/Users/indraimar/Desktop/DH Projects/JR3.txt', encoding = 'utf-8').read()

# %% [markdown]
# ### Removing Punctuation

# %%
from string import punctuation

# %%
def remove_punctuation(song):
# Removes all punctuation from a song
    for char in punctuation:
        song = song.replace(char, "")
    return song

# %%
nipsey_1 = remove_punctuation(nipsey_1)
nipsey_2 = remove_punctuation(nipsey_2)
nipsey_3 = remove_punctuation(nipsey_3)
schoolboy_1 = remove_punctuation(schoolboy_1)
schoolboy_2 = remove_punctuation(schoolboy_2)
schoolboy_3 = remove_punctuation(schoolboy_3)
yg_1 = remove_punctuation(yg_1)
yg_2 = remove_punctuation(yg_2)
yg_3 = remove_punctuation(yg_3)
jayrock_1 = remove_punctuation(jayrock_1)
jayrock_2 = remove_punctuation(jayrock_2)
jayrock_3 = remove_punctuation(jayrock_3)

# %% [markdown]
# ### Making Lowercase

# %%
def lowercase(song):
    # Converts string to lowercase
    lowercase_song = song.lower()
    return lowercase_song

# %%
nipsey_1 = lowercase(nipsey_1)
nipsey_2 = lowercase(nipsey_2)
nipsey_3 = lowercase(nipsey_3)
schoolboy_1 = lowercase(schoolboy_1)
schoolboy_2 = lowercase(schoolboy_2)
schoolboy_3 = lowercase(schoolboy_3)
yg_1 = lowercase(yg_1)
yg_2 = lowercase(yg_2)
yg_3 = lowercase(yg_3)
jayrock_1 = lowercase(jayrock_1)
jayrock_2 = lowercase(jayrock_2)
jayrock_3 = lowercase(jayrock_3)

# %% [markdown]
# ### Tokenization

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download("stopwords")
nltk.download("punkt")
nltk.download("averaged_perceptron_tagger")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/indraimar/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/indraimar/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/indraimar/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
nipsey_1 = word_tokenize(nipsey_1)
nipsey_2 = word_tokenize(nipsey_2)
nipsey_3 = word_tokenize(nipsey_3)
schoolboy_1 = word_tokenize(schoolboy_1)
schoolboy_2 = word_tokenize(schoolboy_2)
schoolboy_3 = word_tokenize(schoolboy_3)
yg_1 = word_tokenize(yg_1)
yg_2 = word_tokenize(yg_2)
yg_3 = word_tokenize(yg_3)
jayrock_1 = word_tokenize(jayrock_1)
jayrock_2 = word_tokenize(jayrock_2)
jayrock_3 = word_tokenize(jayrock_3)

# %% [markdown]
# ### Removing Stopwords

# %%
from nltk.corpus import stopwords

# %%
def no_stops(song):
    # Removes stop words
    no_stops = [word for word in song if word not in stopwords.words('english')]
    return no_stops

# %%
nipsey_1 = no_stops(nipsey_1)
nipsey_2 = no_stops(nipsey_2)
nipsey_3 = no_stops(nipsey_3)
schoolboy_1 = no_stops(schoolboy_1)
schoolboy_2 = no_stops(schoolboy_2)
schoolboy_3 = no_stops(schoolboy_3)
yg_1 = no_stops(yg_1)
yg_2 = no_stops(yg_2)
yg_3 = no_stops(yg_3)
jayrock_1 = no_stops(jayrock_1)
jayrock_2 = no_stops(jayrock_2)
jayrock_3 = no_stops(jayrock_3)

# %% [markdown]
# ## Frequency Analysis

# %%
from collections import Counter

# %%
def frequency(song):
    # Determines the frequency of each non-stopword in the song
    freq = Counter(song)
    return freq.most_common()

# %%
nipsey_1 = frequency(nipsey_1)
nipsey_2 = frequency(nipsey_2)
nipsey_3 = frequency(nipsey_3)
schoolboy_1 = frequency(schoolboy_1)
schoolboy_2 = frequency(schoolboy_2)
schoolboy_3 = frequency(schoolboy_3)
yg_1 = frequency(yg_1)
yg_2 = frequency(yg_2)
yg_3 = frequency(yg_3)
jayrock_1 = frequency(jayrock_1)
jayrock_2 = frequency(jayrock_2)
jayrock_3 = frequency(jayrock_3)

# %% [markdown]
# ## Conversion to DataFrames

# %%
def convert_to_dataframe(song):
    # Converts song word frequencies into a dataframe
    df = pd.DataFrame(song, columns = ['Word', 'Frequency'])
    return df

# %%
nipsey_1 = convert_to_dataframe(nipsey_1)
nipsey_2 = convert_to_dataframe(nipsey_2)
nipsey_3 = convert_to_dataframe(nipsey_3)
schoolboy_1 = convert_to_dataframe(schoolboy_1)
schoolboy_2 = convert_to_dataframe(schoolboy_2)
schoolboy_3 = convert_to_dataframe(schoolboy_3)
yg_1 = convert_to_dataframe(yg_1)
yg_2 = convert_to_dataframe(yg_2)
yg_3 = convert_to_dataframe(yg_3)
jayrock_1 = convert_to_dataframe(jayrock_1)
jayrock_2 = convert_to_dataframe(jayrock_2)
jayrock_3 = convert_to_dataframe(jayrock_3)

# %% [markdown]
# ## POS Tagging

# %%
from nltk import pos_tag

# %%
def pos_tagger(DataFrame):
    # Part of speech tags each non-stopword
    tagged = pos_tag(DataFrame['Word'])
    return tagged

# %%
nipsey_1['POS Tag'] = pos_tagger(nipsey_1)
nipsey_2['POS Tag'] = pos_tagger(nipsey_2)
nipsey_3['POS Tag'] = pos_tagger(nipsey_3)
schoolboy_1['POS Tag'] = pos_tagger(schoolboy_1)
schoolboy_2['POS Tag'] = pos_tagger(schoolboy_2)
schoolboy_3['POS Tag'] = pos_tagger(schoolboy_3)
yg_1['POS Tag'] = pos_tagger(yg_1)
yg_2['POS Tag'] = pos_tagger(yg_2)
yg_3['POS Tag'] = pos_tagger(yg_3)
jayrock_1['POS Tag'] = pos_tagger(jayrock_1)
jayrock_2['POS Tag'] = pos_tagger(jayrock_2)
jayrock_3['POS Tag'] = pos_tagger(jayrock_3)

# %%
pd.options.display.max_rows = 1000

# %%
nipsey_1
# Out:
#             Word  Frequency            POS Tag
# 0         mhmmhm         15       (mhmmhm, NN)
# 1           yeah         14         (yeah, NN)
# 2            got          8         (got, VBD)
# 3            v12          7          (v12, JJ)
# 4           shit          6         (shit, NN)
# 5          nigga          6        (nigga, JJ)
# 6          round          5        (round, NN)
# 7          racks          5       (racks, VBZ)
# 8         middle          5       (middle, JJ)
# 9           cant          5         (cant, JJ)
# 10         ridin          4        (ridin, NN)
# 11           let          4          (let, NN)
# 12           dog          4          (dog, VB)
# 13          drop          4         (drop, VB)
# 14         check          4        (check, VB)
# 15           new          4          (new, JJ)
# 16          neck          4         (neck, NN)
# 17           put          4         (put, VBD)
# 18            em          4           (em, RB)
# ...

# %% [markdown]
# ## Visualization

# %%
import math
import random

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rc('savefig', dpi=200)
plt.style.use('classic')
plt.rcParams['xtick.minor.size'] = 0
plt.rcParams['ytick.minor.size'] = 0

# %% [markdown]
# ### Word Frequency Barplot

# %%
def make_barplot(DataFrame): 
    # makes barplot based on frequency
    barplot = DataFrame.plot.bar(x = 'Word', y = 'Frequency', 
                                  rot = 45, 
                                  title = "Word Frequency Barplot",
                                  width = 0.5,
                                  figsize = (50, 20));

    plt.xlabel("Word");
    plt.ylabel("Frequency");
    return barplot
# Save this figure by unhashtagging the cell and rerunning it
# plt.savefig('barplot.tiff')

# %%
make_barplot(nipsey_1)
#plt.savefig('nipsey_1.tiff')

# %% [markdown]
# ### Word Length Barplot

# %%
def longest_words(DataFrame):
    DataFrame.index = DataFrame['Word'].str.len()
    longest = DataFrame.sort_index(ascending = False).rename_axis('Length').reset_index()
    return longest

# %%
def word_length(DataFrame):
    df = DataFrame[['Word']]
    return list(df['Word'])#.sort(key = len)

# %%
nipsey_1 = longest_words(nipsey_1)
nipsey_2 = longest_words(nipsey_2)
nipsey_3 = longest_words(nipsey_3)
schoolboy_1 = longest_words(schoolboy_1)
schoolboy_2 = longest_words(schoolboy_2)
schoolboy_3 = longest_words(schoolboy_3)
yg_1 = longest_words(yg_1)
yg_2 = longest_words(yg_2)
yg_3 = longest_words(yg_3)
jayrock_1 = longest_words(jayrock_1)
jayrock_2 = longest_words(jayrock_2)
jayrock_3 = longest_words(jayrock_3)

# %%
schoolboy_2
#nipsey_1.to_csv('nipsey_1.csv')
# Out:
#      Length          Word  Frequency             POS Tag
# 0        12  fourfourfive          1  (fourfourfive, VB)
# 1        12  jackinthebox          3  (jackinthebox, NN)
# 2         9     kickstand          1     (kickstand, CD)
# 3         8      subtract          1      (subtract, NN)
# 4         8      reclined          1     (reclined, VBN)
# 5         8      straight          1      (straight, RB)
# 6         8      backtalk          2      (backtalk, NN)
# 7         7       twodoor          3       (twodoor, JJ)
# 8         7       talking          1      (talking, VBG)
# 9         7       staying          1      (staying, VBG)
# 10        7       telling          1      (telling, VBG)
# 11        7       thirtys          3       (thirtys, NN)
# 12        7       another          1       (another, DT)
# 13        7       pockets          1      (pockets, NNS)
# 14        7       blowing          1      (blowing, VBG)
# ...

# %%
def make_barplot_longest(DataFrame):  
    barplot_1 = DataFrame.plot.bar(x = 'Word' , y = 'Length',
                                  rot = 45, 
                                  title = "Word Length Barplot",
                                  width = 0.5,
                                  figsize = (50,20));

    plt.xlabel("Word");
    plt.ylabel("Length");
    return barplot_1

# %%
make_barplot_longest(nipsey_1)
#plt.savefig('nipsey_1_length.tiff')

# %% [markdown]
# ### Summary Statistics

# %%
def statistics(DataFrame):
    stats = DataFrame.describe()
    return stats

# %%
statistics(nipsey_1)
# Out:
#            Length   Frequency
# count  215.000000  215.000000
# mean     5.246512    1.762791
# std      1.726558    1.744018
# min      2.000000    1.000000
# 25%      4.000000    1.000000
# 50%      5.000000    1.000000
# 75%      6.000000    2.000000
# max     11.000000   15.000000

# %% [markdown]
# ### Findings

# %% [markdown]
# There were no clear distinctions between the two sides of the rag, with all of the artists emphasizing the pursuit of success, both financially and through public perception. The same indicators of status are used throughout the songs, with cars, jewelry, and other material goods used to reinforce their wealth. All of the artists similarly engage in acknowledgement of the trials and tribulations they have gone through in orfer to achieve what they have, noting the sacrifices made and the friends lost in that pursuit. However, I did notice a difference in the emphasis put on gang affiliation between the two sides, with the bloods generally being far more up front about their banging than the crips (pressing the message as opposed to simply recognizing it). The language used, too, was somewhat different, with Nipsey Hussle, ScHoolboy Q, and Jay Rock generally having longer, more complex words and lyricism when compared to YG. Words such as entrepeneurship, commercial, and enterprise appearing in Nipsey's music points to a particular economic focus when compared to the others, while ScHoolboy Q uses terms such as chromosome, fragrance, and kickstand, all indicate a higher mastery of rhyming schemes when compared to the blood/piru rappers.
#
# This analysis was somewhat biased by the inclusion of the songs' choruses in the dataset, as hip hop and rap choruses generally tend to be repetitive in terms of word usage. This naturally trended the word frequency values towards words in the choruses, as opposed to those within the actual verses. Similarly, more normalization of the data is needed (lemmitization perhaps) as many words were recounted due to inflection caused mispellings. For example, in Man of the Year, the word 'bounce' was counted differently from the word 'bbbbounce', due to the emphasis on the latter's first letter.
#
# My expectations were somewhat proven correct, though a sample of 3 songs is hardly enough by which to judge an artists thematic and lyrical spectrum. Crip rappers, Nipsey Hussle in particular, proved to engage in more diverse and complex topics when compared to their blood counterparts, who in turn followed the expecation of emphasizing their credentials more. As stated, however, 12 songs is not enough to make a definitve statement/conclusion.
